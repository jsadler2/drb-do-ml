# %%
import numpy as np
from river_dl.postproc_utils import prepped_array_to_df
import seaborn as sns

# %%
data = np.load("0_baseline_LSTM/prepped.npz", allow_pickle=True)

# %%
val_sites = ["01472104", "01473500", "01481500"]

# %%
df_trn = prepped_array_to_df(data['y_obs_trn'],
                                      data['times_trn'],
                                       data['ids_trn'],
                                       col_names=data['y_obs_vars'])
df_trn_val_sites = df_trn[df_trn.seg_id_nat.isin(val_sites)]

# %%
sns.relplot(x='date', y='do_min', col='seg_id_nat', data=df_trn_val_sites)

# %%
df_trn_val_sites.do_mean.notna().sum()
# Out:
# 9416

# %%
import xarray as xr

# %%
ds = xr.open_zarr("../well_observed_trn_targets.zarr/")

# %%
ds.site_id
# Out:
# <xarray.DataArray 'site_id' (site_id: 10)>
# array(['01466500', '01472119', '01473499', '01473675', '01473780', '01474500',
#        '01480617', '01480870', '01481000', '01481500'], dtype=object)
# Coordinates:
#   * site_id  (site_id) object '01466500' '01472119' ... '01481000' '01481500'
